# %% [markdown]
# # Your First Python Instruction
#
# Predict what the instruction below will display. Select its cell and press the triangular **Run** button or **Shift+Enter**.

# %%
print("Community Arts Centre")

# %% [markdown]
# Compare the result with your prediction. The displayed name should be `Community Arts Centre`, without quotation marks.
