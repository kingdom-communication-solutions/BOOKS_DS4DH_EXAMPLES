# %% [markdown]
# # Understanding `print()`
#
# Use these cells alongside the section in the book.
#
# ## Change it and observe
#
# Identify the function name, parentheses, quotation marks, and supplied value. Replace the text with your name, a language, or a field that interests you. Predict the result, run the cell, and compare.

# %%
print("Community Arts Centre")

# %% [markdown]
# ## Grow the program
#
# Before running the announcement, predict how many lines will appear, whether the quotation marks will appear, and whether the line beginning with `#` will appear. Run it and compare with your predictions.

# %%
# Publish a community event announcement.
print("Community Arts Centre")
print("Community Storytelling Evening")
print("Berlin | 18 October 2026 | 18:30")
print("Welcome! Willkommen! Bienvenue! Karibu!")
print("Planned capacity:", 120)

# %% [markdown]
# ## Data, code, and output
#
# The announcement shows a basic purpose of programming: writing instructions that use data to produce a useful result. **Programming** involves designing and writing those instructions; their written form in a programming language is called **code**.
#
# **Data** are representations of facts or ideas in a form that can be stored, communicated, or processed—for example, an event name written as text or a capacity written as a number. **Information** is the meaning those representations convey in context.[^data-information] The number `120` alone does not tell us what it counts; the label `Planned capacity:` tells us that it refers to the number of places planned for the event.
#
# In our program, the title, location, date, greetings, and capacity are data. The five `print()` calls are code that displays them. The displayed announcement is the program’s **output**, the result it produces. Here, the output communicates the event information we supplied; the program does not discover or calculate new facts. Consider the title line:
#
# ```python
# print("Community Storytelling Evening")
# ```
#
# The title `Community Storytelling Evening` is the data. The complete `print()` instruction is the code that displays it, producing this output:
#
# ```text
# Community Storytelling Evening
# ```
#
# Python displays the title we supplied. Changing the text inside the quotation marks changes the output; it does not change what `print()` does.
#
# ## A note for the reader
#
# The program also contains a line that produces no output:
#
# ```python
# # Publish a community event announcement.
# ```
#
# This is a **comment**, a note for someone reading the code. Outside quotation marks, `#` begins a comment that Python ignores for the rest of that line. Here, it explains why the program was written. That is why the program has six written lines but displays only five.
#
# ## Two values on one line
#
# The final instruction differs from the others because it supplies two arguments:
#
# ```python
# print("Planned capacity:", 120)
# ```
#
# The comma separates the label `"Planned capacity:"` from the number `120`. With this call, `print()` displays both values on one line, putting a space between them:
#
# ```text
# Planned capacity: 120
# ```
#
# The label tells the reader what the number means. The comma belongs to the instruction and is not displayed.
#
#
# [^data-information]: Definitions paraphrased from the NIST Computer Security Resource Center glossary, “Data” (https://csrc.nist.gov/glossary/term/data) and “Information” (https://csrc.nist.gov/glossary/term/information), drawing on its representation and contextual-meaning definitions.

# %% [markdown]
# ## Adapt the announcement
#
# Add a greeting in a language you know, keeping all greetings inside the same pair of quotation marks. Then change the event title. Predict the affected output before each change, run the announcement cell again, and check the result.
#
# Explain which part is data, which instruction displays it, why the comment produces no output, and how the final call displays its two arguments.
