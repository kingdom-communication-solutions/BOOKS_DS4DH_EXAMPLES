# %% [markdown]
# # Building and Formatting Messages
#
# These are the worked examples from this section. Predict each result, run the cell, compare, make one change, and explain it. Follow the book for the associated investigation.

# %%
event_title = "Community Storytelling Evening"
capacity = 120
message = f"{event_title} — planned capacity: {capacity}"
print(message)

# %%
greeting = "Welcome" + " to the evening!"
print(greeting)

# %%
print("Welcome!\nBienvenue!")
