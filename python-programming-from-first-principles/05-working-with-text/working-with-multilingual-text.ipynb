# %% [markdown]
# # Working With Multilingual Text
#
# These are the worked examples from this section. Predict each result, run the cell, compare, make one change, and explain it. Follow the book for the associated investigation.

# %%
print("Bienvenue à la soirée !")
print("Willkommen zum Erzählabend!")
print("Karibu kwenye jioni ya hadithi!")
print("مرحبًا بكم")

# %%
name = "Chloé"
print(name)
print(len(name))
